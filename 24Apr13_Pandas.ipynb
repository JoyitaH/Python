# %%
import pandas as pd

# %%
data = pd.read_csv("insurance.csv")
data.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# Filtering
data['gender'] == 'female'
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1333    False
# 1334     True
# 1335     True
# 1336     True
# 1337     True
# Name: gender, Length: 1338, dtype: bool

# %%
data[data['gender'] == 'female']
# Out:
#       age  gender    bmi  children smoker     region      charges
# 0      19  female  27.90         0    yes  southwest  16884.92400
# 5      31  female  25.74         0     no  southeast   3756.62160
# 6      46  female  33.44         1     no  southeast   8240.58960
# 7      37  female  27.74         3     no  northwest   7281.50560
# 9      60  female  25.84         0     no  northwest  28923.13692
# ...   ...     ...    ...       ...    ...        ...          ...
# 1332   52  female  44.70         3     no  southwest  11411.68500
# 1334   18  female  31.92         0     no  northeast   2205.98080
# 1335   18  female  36.85         0     no  southeast   1629.83350
# 1336   21  female  25.80         0     no  southwest   2007.94500
# 1337   61  female  29.07         0    yes  northwest  29141.36030
#
# [662 rows x 7 columns]

# %%
data[data['gender'] == 'female'][['age', 'region', 'charges']]
# Out:
#       age     region      charges
# 0      19  southwest  16884.92400
# 5      31  southeast   3756.62160
# 6      46  southeast   8240.58960
# 7      37  northwest   7281.50560
# 9      60  northwest  28923.13692
# ...   ...        ...          ...
# 1332   52  southwest  11411.68500
# 1334   18  northeast   2205.98080
# 1335   18  southeast   1629.83350
# 1336   21  southwest   2007.94500
# 1337   61  northwest  29141.36030
#
# [662 rows x 3 columns]

# %%
data[data['age'] > 50]
# Out:
#       age  gender    bmi  children smoker     region      charges
# 9      60  female  25.84         0     no  northwest  28923.13692
# 11     62  female  26.29         0    yes  southeast  27808.72510
# 13     56  female  39.82         0     no  southeast  11090.71780
# 16     52  female  30.78         1     no  northeast  10797.33620
# 18     56    male  40.30         0     no  southwest  10602.38500
# ...   ...     ...    ...       ...    ...        ...          ...
# 1327   51    male  30.03         1     no  southeast   9377.90470
# 1329   52    male  38.60         2     no  southwest  10325.20600
# 1330   57  female  25.74         2     no  southeast  12629.16560
# 1332   52  female  44.70         3     no  southwest  11411.68500
# 1337   61  female  29.07         0    yes  northwest  29141.36030
#
# [356 rows x 7 columns]

# %%
# Lambda function => anonymous function
data['upd_children'] = data['children'].apply(lambda x : x+1)

# %%
data.head()
# Out:
#    age  gender     bmi  children smoker     region      charges  upd_children
# 0   19  female  27.900         0    yes  southwest  16884.92400             1
# 1   18    male  33.770         1     no  southeast   1725.55230             2
# 2   28    male  33.000         3     no  southeast   4449.46200             4
# 3   33    male  22.705         0     no  northwest  21984.47061             1
# 4   32    male  28.880         0     no  northwest   3866.85520             1

# %%
data['gender'].apply(lambda x : 1 if x == 'female' else 0)
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1333    0
# 1334    1
# 1335    1
# 1336    1
# 1337    1
# Name: gender, Length: 1338, dtype: int64

# %%
def age_group(x):
    if(x < 20):
        return '0-20'
    elif(x > 20 and x < 40):
        return '20-40'
    elif(x > 40 and x < 60):
        return '40-60'
    else:
        return '60+'

# %%
data['age_group'] = data['age'].apply(age_group)

# %%
data.head()
# Out:
#    age  gender     bmi  children smoker     region      charges  upd_children  \
# 0   19  female  27.900         0    yes  southwest  16884.92400             1
# 1   18    male  33.770         1     no  southeast   1725.55230             2
# 2   28    male  33.000         3     no  southeast   4449.46200             4
# 3   33    male  22.705         0     no  northwest  21984.47061             1
# 4   32    male  28.880         0     no  northwest   3866.85520             1
#
#   age_group
# 0      0-20
# 1      0-20
# 2     20-40
# 3     20-40
# 4     20-40

# %%
# filter data with charges between 10000 and 20000
data[(data['charges'] > 10000) & (data['charges'] < 20000)]
# Out:
#       age  gender     bmi  children smoker     region      charges  \
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 13     56  female  39.820         0     no  southeast  11090.71780
# 16     52  female  30.780         1     no  northeast  10797.33620
# 18     56    male  40.300         0     no  southwest  10602.38500
# 20     60  female  36.005         0     no  northeast  13228.84695
# ...   ...     ...     ...       ...    ...        ...          ...
# 1329   52    male  38.600         2     no  southwest  10325.20600
# 1330   57  female  25.740         2     no  southeast  12629.16560
# 1331   23  female  33.400         0     no  southwest  10795.93733
# 1332   52  female  44.700         3     no  southwest  11411.68500
# 1333   50    male  30.970         3     no  northwest  10600.54830
#
#       upd_children age_group
# 0                1      0-20
# 13               1     40-60
# 16               2     40-60
# 18               1     40-60
# ...

# %%
# Descriptive Statistics
data.describe()
# Out:
#                age          bmi     children       charges  upd_children
# count  1338.000000  1338.000000  1338.000000   1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265      2.094918
# std      14.049960     6.098187     1.205493  12110.011237      1.205493
# min      18.000000    15.960000     0.000000   1121.873900      1.000000
# 25%      27.000000    26.296250     0.000000   4740.287150      1.000000
# 50%      39.000000    30.400000     1.000000   9382.033000      2.000000
# 75%      51.000000    34.693750     2.000000  16639.912515      3.000000
# max      64.000000    53.130000     5.000000  63770.428010      6.000000

# %% [markdown]
# Visualization

# %%
data.head()
# Out:
#    age  gender     bmi  children smoker     region      charges  upd_children  \
# 0   19  female  27.900         0    yes  southwest  16884.92400             1
# 1   18    male  33.770         1     no  southeast   1725.55230             2
# 2   28    male  33.000         3     no  southeast   4449.46200             4
# 3   33    male  22.705         0     no  northwest  21984.47061             1
# 4   32    male  28.880         0     no  northwest   3866.85520             1
#
#   age_group
# 0      0-20
# 1      0-20
# 2     20-40
# 3     20-40
# 4     20-40

# %%
import matplotlib.pyplot as plt

# %%
region_dist = data['region'].value_counts().reset_index()
region_dist
# Out:
#        index  region
# 0  southeast     364
# 1  southwest     325
# 2  northwest     325
# 3  northeast     324

# %%
plt.bar(region_dist['index'], region_dist['region'])
plt.show()

# %%
plt.scatter(data['bmi'], data['charges'])

# %%
plt.scatter(data['age'], data['charges'])

# %%
import seaborn as sns

# %%
sns.countplot(x = 'region', data = data)

# %%
sns.countplot(x = 'region', data = data, palette = ['blue'])
